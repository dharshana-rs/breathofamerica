# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
colspecs = [
    (0 ,2),  #_____ _STATE
    (16 ,18),  #_____ FMONTH
    (18 ,26),  #_____ IDATE
    (18 ,20),  #_____ IMONTH
    (20 ,22),  #_____ IDAY
    (22 ,26),  #_____ IYEAR
    (31 ,35),  #_____ DISPCODE
    (35 ,45),  #_____ SEQNO
    (35 ,45),  #_____ _PSU
    (62 ,63),  #_____ CTELENM1
    (63 ,64),  #_____ PVTRESD1
    (64 ,65),  #_____ COLGHOUS
    (65 ,66),  #_____ STATERE1
    (66 ,67),  #_____ CELPHON1
    (67 ,68),  #_____ LADULT1
    (68 ,70),  #_____ NUMADULT
    (70 ,71),  #_____ RESPSLC1
    (71 ,72),  #_____ LANDSEX2
    (73 ,74),  #_____ SAFETIME
    (74 ,75),  #_____ CTELNUM1
    (75 ,76),  #_____ CELLFON5
    (76 ,77),  #_____ CADULT1
    (77 ,78),  #_____ CELLSEX2
    (79 ,80),  #_____ PVTRESD3
    (80 ,81),  #_____ CCLGHOUS
    (81 ,82),  #_____ CSTATE1
    (84 ,85),  #_____ LANDLINE
    (85 ,87),  #_____ HHADULT
    (87 ,88),  #_____ SEXVAR
    (100 ,101),  #_____ GENHLTH
    (101 ,103),  #_____ PHYSHLTH
    (103 ,105),  #_____ MENTHLTH
    (105 ,107),  #_____ POORHLTH
    (107 ,109),  #_____ PRIMINS1
    (109 ,110),  #_____ PERSDOC3
    (110 ,111),  #_____ MEDCOST1
    (111 ,112),  #_____ CHECKUP1
    (112 ,113),  #_____ EXERANY2
    (113 ,115),  #_____ EXRACT12
    (115 ,118),  #_____ EXEROFT1
    (118 ,121),  #_____ EXERHMM1
    (121 ,123),  #_____ EXRACT22
    (123 ,126),  #_____ EXEROFT2
    (126 ,129),  #_____ EXERHMM2
    (129 ,132),  #_____ STRENGTH
    (132 ,133),  #_____ BPHIGH6
    (133 ,134),  #_____ BPMEDS1
    (134 ,135),  #_____ CHOLCHK3
    (135 ,136),  #_____ TOLDHI3
    (136 ,137),  #_____ CHOLMED3
    (137 ,138),  #_____ CVDINFR4
    (138 ,139),  #_____ CVDCRHD4
    (139 ,140),  #_____ CVDSTRK3
    (140 ,141),  #_____ ASTHMA3
    (141 ,142),  #_____ ASTHNOW
    (142 ,143),  #_____ CHCSCNC1
    (143 ,144),  #_____ CHCOCNC1
    (144 ,145),  #_____ CHCCOPD3
    (145 ,146),  #_____ ADDEPEV3
    (146 ,147),  #_____ CHCKDNY2
    (147 ,148),  #_____ HAVARTH4
    (148 ,149),  #_____ DIABETE4
    (149 ,151),  #_____ DIABAGE4
    (185 ,186),  #_____ MARITAL
    (186 ,187),  #_____ EDUCA
    (187 ,188),  #_____ RENTHOM1
    (196 ,197),  #_____ NUMHHOL4
    (197 ,198),  #_____ NUMPHON4
    (198 ,199),  #_____ CPDEMO1C
    (199 ,200),  #_____ VETERAN3
    (200 ,201),  #_____ EMPLOY1
    (201 ,203),  #_____ CHILDREN
    (203 ,205),  #_____ INCOME3
    (205 ,206),  #_____ PREGNANT
    (206 ,210),  #_____ WEIGHT2
    (210 ,214),  #_____ HEIGHT3
    (214 ,215),  #_____ DEAF
    (215 ,216),  #_____ BLIND
    (216 ,217),  #_____ DECIDE
    (217 ,218),  #_____ DIFFWALK
    (218 ,219),  #_____ DIFFDRES
    (219 ,220),  #_____ DIFFALON
    (220 ,222),  #_____ FALL12MN
    (222 ,224),  #_____ FALLINJ5
    (224 ,225),  #_____ SMOKE100
    (225 ,226),  #_____ SMOKDAY2
    (226 ,227),  #_____ USENOW3
    (227 ,228),  #_____ ECIGNOW2
    (228 ,231),  #_____ ALCDAY4
    (231 ,233),  #_____ AVEDRNK3
    (233 ,235),  #_____ DRNK3GE5
    (235 ,237),  #_____ MAXDRNKS
    (237 ,238),  #_____ FLUSHOT7
    (238 ,244),  #_____ FLSHTMY3
    (244 ,245),  #_____ PNEUVAC4
    (245 ,246),  #_____ SHINGLE2
    (246 ,247),  #_____ HIVTST7
    (247 ,253),  #_____ HIVTSTD3
    (253 ,254),  #_____ SEATBELT
    (254 ,256),  #_____ DRNKDRI2
    (256 ,257),  #_____ COVIDPO1
    (257 ,258),  #_____ COVIDSM1
    (258 ,259),  #_____ COVIDACT
    (259 ,260),  #_____ PDIABTS1
    (260 ,261),  #_____ PREDIAB2
    (261 ,262),  #_____ DIABTYPE
    (262 ,263),  #_____ INSULIN1
    (263 ,265),  #_____ CHKHEMO3
    (265 ,266),  #_____ EYEEXAM1
    (266 ,267),  #_____ DIABEYE1
    (267 ,268),  #_____ DIABEDU1
    (268 ,269),  #_____ FEETSORE
    (269 ,270),  #_____ ARTHEXER
    (270 ,271),  #_____ ARTHEDU
    (271 ,272),  #_____ LMTJOIN3
    (272 ,273),  #_____ ARTHDIS2
    (273 ,275),  #_____ JOINPAI2
    (275 ,278),  #_____ LCSFIRST
    (278 ,281),  #_____ LCSLAST
    (281 ,284),  #_____ LCSNUMCG
    (284 ,285),  #_____ LCSCTSC1
    (285 ,286),  #_____ LCSSCNCR
    (286 ,287),  #_____ LCSCTWHN
    (287 ,288),  #_____ HADMAM
    (288 ,289),  #_____ HOWLONG
    (289 ,290),  #_____ CERVSCRN
    (290 ,291),  #_____ CRVCLCNC
    (291 ,292),  #_____ CRVCLPAP
    (292 ,293),  #_____ CRVCLHPV
    (293 ,294),  #_____ HADHYST2
    (294 ,295),  #_____ PSATEST1
    (295 ,296),  #_____ PSATIME1
    (296 ,297),  #_____ PCPSARS2
    (297 ,298),  #_____ PSASUGS1
    (298 ,299),  #_____ PCSTALK2
    (299 ,300),  #_____ HADSIGM4
    (300 ,301),  #_____ COLNSIGM
    (301 ,302),  #_____ COLNTES1
    (302 ,303),  #_____ SIGMTES1
    (303 ,304),  #_____ LASTSIG4
    (304 ,305),  #_____ COLNCNCR
    (305 ,306),  #_____ VIRCOLO1
    (306 ,307),  #_____ VCLNTES2
    (307 ,308),  #_____ SMALSTOL
    (308 ,309),  #_____ STOLTEST
    (309 ,310),  #_____ STOOLDN2
    (310 ,311),  #_____ BLDSTFIT
    (311 ,312),  #_____ SDNATES1
    (312 ,313),  #_____ CNCRDIFF
    (313 ,315),  #_____ CNCRAGE
    (315 ,317),  #_____ CNCRTYP2
    (317 ,318),  #_____ CSRVTRT3
    (318 ,320),  #_____ CSRVDOC1
    (320 ,321),  #_____ CSRVSUM
    (321 ,322),  #_____ CSRVRTRN
    (322 ,323),  #_____ CSRVINST
    (323 ,324),  #_____ CSRVINSR
    (324 ,325),  #_____ CSRVDEIN
    (325 ,326),  #_____ CSRVCLIN
    (326 ,327),  #_____ CSRVPAIN
    (327 ,328),  #_____ CSRVCTL2
    (328 ,331),  #_____ INDORTAN
    (331 ,334),  #_____ NUMBURN3
    (334 ,335),  #_____ SUNPRTCT
    (335 ,337),  #_____ WKDAYOUT
    (337 ,339),  #_____ WKENDOUT
    (339 ,340),  #_____ CIMEMLO1
    (340 ,341),  #_____ CDWORRY
    (341 ,342),  #_____ CDDISCU1
    (342 ,343),  #_____ CDHOUS1
    (343 ,344),  #_____ CDSOCIA1
    (344 ,345),  #_____ CAREGIV1
    (345 ,347),  #_____ CRGVREL4
    (347 ,348),  #_____ CRGVLNG1
    (348 ,349),  #_____ CRGVHRS1
    (349 ,351),  #_____ CRGVPRB3
    (351 ,352),  #_____ CRGVALZD
    (352 ,353),  #_____ CRGVPER1
    (353 ,354),  #_____ CRGVHOU1
    (354 ,355),  #_____ CRGVEXPT
    (355 ,357),  #_____ LASTSMK2
    (357 ,358),  #_____ STOPSMK2
    (358 ,359),  #_____ MENTCIGS
    (359 ,360),  #_____ MENTECIG
    (360 ,361),  #_____ HEATTBCO
    (361 ,362),  #_____ FIREARM5
    (362 ,363),  #_____ GUNLOAD
    (363 ,364),  #_____ LOADULK2
    (564 ,565),  #_____ HASYMP1
    (565 ,566),  #_____ HASYMP2
    (566 ,567),  #_____ HASYMP3
    (567 ,568),  #_____ HASYMP4
    (568 ,569),  #_____ HASYMP5
    (569 ,570),  #_____ HASYMP6
    (570 ,571),  #_____ STRSYMP1
    (571 ,572),  #_____ STRSYMP2
    (572 ,573),  #_____ STRSYMP3
    (573 ,574),  #_____ STRSYMP4
    (574 ,575),  #_____ STRSYMP5
    (575 ,576),  #_____ STRSYMP6
    (576 ,577),  #_____ FIRSTAID
    (577 ,578),  #_____ ASPIRIN
    (579 ,580),  #_____ SOMALE
    (580 ,581),  #_____ SOFEMALE
    (582 ,584),  #_____ MARIJAN1
    (584 ,585),  #_____ MARJSMOK
    (585 ,586),  #_____ MARJEAT
    (586 ,587),  #_____ MARJVAPE
    (587 ,588),  #_____ MARJDAB
    (588 ,589),  #_____ MARJOTHR
    (589 ,590),  #_____ USEMRJN4
    (590 ,591),  #_____ ACEDEPRS
    (591 ,592),  #_____ ACEDRINK
    (592 ,593),  #_____ ACEDRUGS
    (593 ,594),  #_____ ACEPRISN
    (594 ,595),  #_____ ACEDIVRC
    (595 ,596),  #_____ ACEPUNCH
    (596 ,597),  #_____ ACEHURT1
    (597 ,598),  #_____ ACESWEAR
    (598 ,599),  #_____ ACETOUCH
    (599 ,600),  #_____ ACETTHEM
    (600 ,601),  #_____ ACEHVSEX
    (601 ,602),  #_____ ACEADSAF
    (602 ,603),  #_____ ACEADNED
    (603 ,605),  #_____ IMFVPLA4
    (605 ,606),  #_____ HPVADVC4
    (606 ,608),  #_____ HPVADSHT
    (608 ,609),  #_____ TETANUS1
    (609 ,610),  #_____ COVIDVA1
    (610 ,611),  #_____ COVACGE1
    (611 ,612),  #_____ COVIDNU2
    (612 ,613),  #_____ LSATISFY
    (613 ,614),  #_____ EMTSUPRT
    (614 ,615),  #_____ SDLONELY
    (615 ,616),  #_____ SDHEMPLY
    (616 ,617),  #_____ FOODSTMP
    (617 ,618),  #_____ SDHFOOD1
    (618 ,619),  #_____ SDHBILLS
    (619 ,620),  #_____ SDHUTILS
    (620 ,621),  #_____ SDHTRNSP
    (621 ,622),  #_____ SDHSTRE1
    (622 ,624),  #_____ RRCLASS3
    (624 ,625),  #_____ RRCOGNT2
    (625 ,626),  #_____ RRTREAT
    (626 ,627),  #_____ RRATWRK2
    (627 ,628),  #_____ RRHCARE4
    (628 ,629),  #_____ RRPHYSM2
    (635 ,636),  #_____ RCSBORG1
    (669 ,670),  #_____ RCSRLTN2
    (670 ,671),  #_____ CASTHDX2
    (671 ,672),  #_____ CASTHNO2
    (676 ,678),  #_____ QSTVER
    (678 ,680),  #_____ QSTLANG
    (1401 ,1402),  #_____ _METSTAT
    (1402 ,1403),  #_____ _URBSTAT
    (1408 ,1409),  #_____ MSCODE
    (1409 ,1415),  #_____ _STSTR
    (1415 ,1425),  #_____ _STRWT
    (1445 ,1455),  #_____ _RAWRAKE
    (1455 ,1465),  #_____ _WT2RAKE
    (1470 ,1472),  #_____ _IMPRACE
    (1481 ,1482),  #_____ _CHISPNC
    (1538 ,1540),  #_____ _CRACE1
    (1566 ,1567),  #_____ CAGEG
    (1582 ,1592),  #_____ _CLLCPWT
    (1679 ,1680),  #_____ _DUALUSE
    (1680 ,1690),  #_____ _DUALCOR
    (1690 ,1700),  #_____ _LLCPWT2
    (1748 ,1758),  #_____ _LLCPWT
    (1896 ,1897),  #_____ _RFHLTH
    (1897 ,1898),  #_____ _PHYS14D
    (1898 ,1899),  #_____ _MENT14D
    (1899 ,1900),  #_____ _HLTHPL1
    (1900 ,1901),  #_____ _HCVU653
    (1901 ,1902),  #_____ _TOTINDA
    (1902 ,1905),  #_____ METVL12_
    (1905 ,1908),  #_____ METVL22_
    (1908 ,1913),  #_____ MAXVO21_
    (1913 ,1918),  #_____ FC601_
    (1918 ,1919),  #_____ ACTIN13_
    (1919 ,1920),  #_____ ACTIN23_
    (1920 ,1923),  #_____ PADUR1_
    (1923 ,1926),  #_____ PADUR2_
    (1926 ,1931),  #_____ PAFREQ1_
    (1931 ,1936),  #_____ PAFREQ2_
    (1936 ,1941),  #_____ _MINAC12
    (1941 ,1946),  #_____ _MINAC22
    (1946 ,1951),  #_____ STRFREQ_
    (1951 ,1952),  #_____ PAMISS3_
    (1952 ,1957),  #_____ PAMIN13_
    (1957 ,1962),  #_____ PAMIN23_
    (1962 ,1967),  #_____ PA3MIN_
    (1967 ,1972),  #_____ PAVIG13_
    (1972 ,1977),  #_____ PAVIG23_
    (1977 ,1982),  #_____ PA3VIGM_
    (1982 ,1983),  #_____ _PACAT3
    (1983 ,1984),  #_____ _PAINDX3
    (1984 ,1985),  #_____ _PA150R4
    (1985 ,1986),  #_____ _PA300R4
    (1986 ,1987),  #_____ _PA30023
    (1987 ,1988),  #_____ _PASTRNG
    (1988 ,1989),  #_____ _PAREC3
    (1989 ,1990),  #_____ _PASTAE3
    (1990 ,1991),  #_____ _RFHYPE6
    (1991 ,1992),  #_____ _CHOLCH3
    (1992 ,1993),  #_____ _RFCHOL3
    (1993 ,1994),  #_____ _MICHD
    (1994 ,1995),  #_____ _LTASTH1
    (1995 ,1996),  #_____ _CASTHM1
    (1996 ,1997),  #_____ _ASTHMS1
    (1997 ,1998),  #_____ _DRDXAR2
    (2054 ,2056),  #_____ _MRACE1
    (2058 ,2059),  #_____ _HISPANC
    (2059 ,2060),  #_____ _RACE
    (2060 ,2061),  #_____ _RACEG21
    (2061 ,2062),  #_____ _RACEGR3
    (2062 ,2063),  #_____ _RACEPRV
    (2063 ,2064),  #_____ _SEX
    (2064 ,2066),  #_____ _AGEG5YR
    (2066 ,2067),  #_____ _AGE65YR
    (2067 ,2069),  #_____ _AGE80
    (2069 ,2070),  #_____ _AGE_G
    (2070 ,2073),  #_____ HTIN4
    (2073 ,2076),  #_____ HTM4
    (2076 ,2081),  #_____ WTKG3
    (2081 ,2085),  #_____ _BMI5
    (2085 ,2086),  #_____ _BMI5CAT
    (2086 ,2087),  #_____ _RFBMI5
    (2087 ,2088),  #_____ _CHLDCNT
    (2088 ,2089),  #_____ _EDUCAG
    (2089 ,2090),  #_____ _INCOMG1
    (2090 ,2091),  #_____ _SMOKER3
    (2091 ,2092),  #_____ _RFSMOK3
    (2092 ,2093),  #_____ _CURECI2
    (2093 ,2094),  #_____ DRNKANY6
    (2094 ,2097),  #_____ DROCDY4_
    (2097 ,2098),  #_____ _RFBING6
    (2098 ,2103),  #_____ _DRNKWK2
    (2103 ,2104),  #_____ _RFDRHV8
    (2104 ,2105),  #_____ _FLSHOT7
    (2105 ,2106),  #_____ _PNEUMO3
    (2106 ,2107),  #_____ _AIDTST4
    (2107 ,2108),  #_____ _RFSEAT2
    (2108 ,2109),  #_____ _RFSEAT3
    (2109 ,2110),  #_____ _DRNKDRV

]

# %%
colnames = [
    "_STATE",
    "FMONTH",
    "IDATE",
    "IMONTH",
    "IDAY",
    "IYEAR",
    "ACTIN23_",
    "PADUR1_",
    "PADUR2_",
    "PAFREQ1_",
    "PAFREQ2_",
    "_MINAC12",
    "_MINAC22",
    "STRFREQ_",
    "PAMISS3_",
    "PAMIN13_",
    "PAMIN23_",
    "PA3MIN_",
    "PAVIG13_",
    "PAVIG23_",
    "PA3VIGM_",
    "_PACAT3",
    "_PAINDX3",
    "_PA150R4",
    "_PA300R4",
    "_PA30023",
    "_PASTRNG",
    "_PAREC3",
    "_PASTAE3",
    "_RFHYPE6",
    "_CHOLCH3",
    "_RFCHOL3",
    "_MICHD",
    "_LTASTH1",
    "_CASTHM1",
    "_ASTHMS1",
    "_DRDXAR2",
    "_MRACE1",
    "_HISPANC",
    "_RACE",
    "_RACEG21",
    "_RACEGR3",
    "_RACEPRV",
    "_SEX",
    "_AGEG5YR",
    "_AGE65YR",
    "_AGE80",
    "_AGE_G",
    "HTIN4",
    "HTM4",
    "WTKG3",
    "_BMI5",
    "_BMI5CAT",
    "_RFBMI5",
    "_CHLDCNT",
    "_EDUCAG",
    "_INCOMG1",
    "_SMOKER3",
    "_RFSMOK3",
    "_CURECI2",
    "DRNKANY6",
    "DROCDY4_",
    "_RFBING6",
    "_DRNKWK2",
    "_RFDRHV8",
    "_FLSHOT7",
    "_PNEUMO3",
    "_AIDTST4",
    "_RFSEAT2",
    "_RFSEAT3",
    "_DRNKDRV"
]

# %%
# Load the fixed-width ASCII file
df = pd.read_fwf('../../Data/2023/LLCP2023.ASC', colspecs=colspecs, names=colnames)

# Save as CSV
df.to_csv('../../Output/brfss_2023.csv', index=False)

df.head(5)
# Out:
#    _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 0       1       1  3012023       3     1   2023      1100  2023000001
# 1       1       1  1062023       1     6   2023      1100  2023000002
# 2       1       1  3082023       3     8   2023      1100  2023000003
# 3       1       1  3062023       3     6   2023      1100  2023000004
# 4       1       1  1062023       1     6   2023      1100  2023000005
#
#          _PSU  CTELENM1  ...  DROCDY4_  _RFBING6  _DRNKWK2  _RFDRHV8  \
# 0  2023000001       1.0  ...         0         1         0         1
# 1  2023000002       1.0  ...         0         1         0         1
# 2  2023000003       1.0  ...         0         1         0         1
# 3  2023000004       1.0  ...         0         1         0         1
# 4  2023000005       1.0  ...         7         1        47         1
#
#    _FLSHOT7  _PNEUMO3  _AIDTST4  _RFSEAT2  _RFSEAT3  _DRNKDRV
# 0       2.0       2.0       2.0         1         1         9
# ...

# %%
# Re-import necessary libraries after environment reset
import re

# Reload the uploaded file
file_path = "../../Data/codebooks/FORMAT23.sas"
with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
    print(f"Reading file : {file_path}")
    sas_text = f.read()
    #print(sas_text)

# Find all VALUE blocks
format_blocks = re.findall(r"(?i)value\s+(\w+)\s+(.*?);", sas_text, re.DOTALL)
#print(format_blocks[0])
#print( type(format_blocks) )

# Convert each block into a dictionary
format_dicts = {}
cleaned_lines = []
codebook_dict = {}
#format_blocks = format_blocks[0]
#item = format_blocks[0]

#print(item)
#print(type(item))
for item in format_blocks:
#for _ in range(0,1):     
    value = item[0]
    lines = item[1].strip().splitlines()
    #print(f"Value : {value}")
    #print(f"Lines : {lines}")
    dict = {}
    for line in lines:
        #print(f"Line : {line}")
        line_arr = line.split("=")
        dict[line_arr[0].strip().replace('"','')] = line_arr[1].strip().replace('"','')
    codebook_dict[value] = dict
    #break

print(codebook_dict)
# Out:
# Reading file : ../../Data/codebooks/FORMAT23.sas
# ...

# %%
# Loop through the codebook and replace codes with descriptions
for col, mapping in codebook_dict.items():
    if col in df.columns:
        df[col] = df[col].astype(str).map(mapping).fillna(df[col])  # fallback to original if unmapped

# Show result
df.head()
# Out:
#     _STATE   FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 0  Alabama  January  3012023       3     1   2023      1100  2023000001
# 1  Alabama  January  1062023       1     6   2023      1100  2023000002
# 2  Alabama  January  3082023       3     8   2023      1100  2023000003
# 3  Alabama  January  3062023       3     6   2023      1100  2023000004
# 4  Alabama  January  1062023       1     6   2023      1100  2023000005
#
#          _PSU  CTELENM1  ...                    DROCDY4_  _RFBING6  _DRNKWK2  \
# 0  2023000001       1.0  ...  No Drink-Occasions per day         1         0
# 1  2023000002       1.0  ...  No Drink-Occasions per day         1         0
# 2  2023000003       1.0  ...  No Drink-Occasions per day         1         0
# 3  2023000004       1.0  ...  No Drink-Occasions per day         1         0
# 4  2023000005       1.0  ...                           7         1        47
#
#    _RFDRHV8  _FLSHOT7  _PNEUMO3  _AIDTST4  _RFSEAT2  _RFSEAT3  \
# ...

# %%
# Export to CSV
df.to_csv("../../Output/decoded_brfss_data.csv", index=False)

# %%
#Try to get 1000 records for sample testing
df_sample = df.head(1000)

# Export to CSV
df_sample.to_csv("../../Output/decoded_brfss_data_sample.csv", index=False)

# %%
#https://aqs.epa.gov/aqsweb/airdata/download_files.html

#AQI by CBSA
aqs_df = pd.read_csv("../../Data/airnow/annual_conc_by_monitor_2023.csv")
aqs_df.head(5)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           88101    3  30.497478
#
#    Longitude  Datum            Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                     Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  PM2.5 - Local Conditions                   1 HOUR  ...
#
#   75th Percentile 50th Percentile 10th Percentile    Local Site Name  \
# ...

# %%
#AQI by CBSA
sites_df = pd.read_csv("../../Data/airnow/aqs_sites.csv")
sites_df.head()
# Out:
#   State Code  County Code  Site Number   Latitude  Longitude  Datum  \
# 0         01            1            1  32.437458 -86.472891  WGS84
# 1         01            1            2  32.428470 -86.443585  WGS84
# 2         01            1            3  32.332659 -86.791521  WGS84
# 3         01            3            1   0.000000   0.000000  NAD27
# 4         01            3            2  30.552367 -87.706911  WGS84
#
#    Elevation      Land Use Location Setting Site Established Date  ...  \
# 0       64.0   RESIDENTIAL         SUBURBAN            1974-05-01  ...
# 1        0.0  AGRICULTURAL            RURAL            1980-01-01  ...
# 2       41.0        FOREST            RURAL            1989-08-31  ...
# 3        0.0       UNKNOWN            RURAL            1959-01-01  ...
# 4        0.0    COMMERCIAL            RURAL            1974-01-01  ...
#
#                            Owning Agency  Local Site Name  \
# 0                     Al Dept Of Env Mgt              NaN
# ...
